# %% [markdown]
# # Mean and Standard Deviation

# %% [markdown]
# ## Global

# %%
import numpy as np
import pandas as pd
import math

anom=pd.read_csv('temperature-anomaly.csv')
anom.drop(['Code'],axis=1,inplace=True)

globe=anom

#1850-1900
a=0
for i in range(0,50):
    a=a+globe.iloc[i,2]
#mean&std1
m1=a/len(range(0,50))

sum1=0
for i in range(0,50):
    sum1=sum1+((globe.iloc[i,2]-m1)**2)

std1=math.sqrt(sum1/(len(range(0,50))-1))
    
#1901-1950
b=0
for i in range(51,100):
    b=b+globe.iloc[i,2]

#mean&std2
m2=b/len(range(51,100))

sum2=0
for i in range(51,100):
    sum2=sum2+((globe.iloc[i,2]-m2)**2)

std2=math.sqrt(sum2/(len(range(51,100))-1))

#1951-2018('present')
c=0
for i in range(101,169):
    c=c+globe.iloc[i,2]

#mean&std3
m3=c/len(range(101,169))

sum3=0
for i in range(101,169):
    sum3=sum3+((globe.iloc[i,2]-m3)**2)

std3=math.sqrt(sum3/(len(range(101,169))-1))


print("the mean of the global median temperature anomalies (C) from 1850 to 1900 is %f with a standard deviation of %f" %(m1,std1))
print("the mean of the global median temperature anomalies (C) from 1901 to 1950 is %f with a standard deviation of %f" %(m2,std2))
print("the mean of the global median temperature anomalies (C) from 1951 to 2018 (present) is %f with a standard deviation of %f\n" %(m3,std3))
# Out:
# the mean of the global median temperature anomalies (C) from 1850 to 1900 is -0.313960 with a standard deviation of 0.108418
# the mean of the global median temperature anomalies (C) from 1901 to 1950 is -0.228082 with a standard deviation of 0.178907
# the mean of the global median temperature anomalies (C) from 1951 to 2018 (present) is 0.175529 with a standard deviation of 0.270916

# %% [markdown]
# ## Northern Hemisphere

# %%
nh=anom.loc[lambda anom: anom['Entity'] == 'Northern Hemisphere']

#1850-1900
a1=0
for i in range(0,50):
    a1=a1+nh.iloc[i,2]
#mean&std4
m4=a1/len(range(0,50))

sum4=0
for i in range(0,50):
    sum4=sum4+((nh.iloc[i,2]-m4)**2)

std4=math.sqrt(sum4/(len(range(0,50))-1))
    
#1901-1950
b1=0
for i in range(51,100):
    b1=b1+nh.iloc[i,2]

#mean&std2
m5=b1/len(range(51,100))

sum5=0
for i in range(51,100):
    sum5=sum5+((nh.iloc[i,2]-m5)**2)

std5=math.sqrt(sum5/(len(range(51,100))-1))

#1951-2018('present')
c1=0
for i in range(101,169):
    c1=c1+nh.iloc[i,2]

#mean&std3
m6=c1/len(range(101,169))

sum6=0
for i in range(101,169):
	sum6=sum6+((nh.iloc[i,2]-m6)**2)

std6=math.sqrt(sum6/(len(range(101,169))-1))

print("the mean of temperature anomalies (in ℃) in the Northern Hemisphere from 1850 to 1900 is %f with a standard deviation of %f" %(m4,std4))
print("the mean of temperature anomalies (in ℃) in the Northern Hemisphere from 1901 to 1950 is %f with a standard deviation of %f" %(m5,std5))
print("the mean of temperature anomalies (in ℃) in the Northern Hemisphere from 1951 to 2018 (present) is %f with a standard deviation of %f\n" %(m6,std6))
# Out:
# the mean of temperature anomalies (in ℃) in the Northern Hemisphere from 1850 to 1900 is -0.280120 with a standard deviation of 0.148005
# the mean of temperature anomalies (in ℃) in the Northern Hemisphere from 1901 to 1950 is -0.174224 with a standard deviation of 0.197997
# the mean of temperature anomalies (in ℃) in the Northern Hemisphere from 1951 to 2018 (present) is 0.239397 with a standard deviation of 0.344614

# %% [markdown]
# ## Southern Hemisphere

# %%
sh=anom.loc[lambda anom: anom['Entity'] == 'Southern Hemisphere']

#1850-1900
a2=0
for i in range(0,50):
    a2=a2+sh.iloc[i,2]
#mean&std4
m7=a2/len(range(0,50))

sum7=0
for i in range(0,50):
    sum7=sum7+((sh.iloc[i,2]-m7)**2)

std7=math.sqrt(sum7/(len(range(0,50))-1))
    
#1901-1950
b2=0
for i in range(51,100):
    b2=b2+sh.iloc[i,2]

#mean&std2
m8=b2/len(range(51,100))

sum8=0
for i in range(51,100):
    sum8=sum8+((sh.iloc[i,2]-m8)**2)

std8=math.sqrt(sum8/(len(range(51,100))-1))

#1951-2018('present')
c2=0
for i in range(101,169):
    c2=c2+sh.iloc[i,2]

#mean&std3
m9=c2/len(range(101,169))

sum9=0
for i in range(101,169):
	sum9=sum9+((sh.iloc[i,2]-m9)**2)

std9=math.sqrt(sum9/(len(range(101,169))-1))

print("the mean of temperature anomalies (in ℃) in the Southern Hemisphere from 1850 to 1900 is %f with a standard deviation of %f" %(m7,std7))
print("the mean of temperature anomalies (in ℃) in the Southern Hemisphere from 1901 to 1950 is %f with a standard deviation of %f" %(m8,std8))
print("the mean of temperature anomalies (in ℃) in the Southern Hemisphere from 1951 to 2018 (present) is %f with a standard deviation of %f\n" %(m9,std9))
# Out:
# the mean of temperature anomalies (in ℃) in the Southern Hemisphere from 1850 to 1900 is -0.348660 with a standard deviation of 0.102040
# the mean of temperature anomalies (in ℃) in the Southern Hemisphere from 1901 to 1950 is -0.283367 with a standard deviation of 0.173422
# the mean of temperature anomalies (in ℃) in the Southern Hemisphere from 1951 to 2018 (present) is 0.111824 with a standard deviation of 0.211466

# %% [markdown]
# ## Tropics

# %%
tropics=anom.loc[lambda anom: anom['Entity'] == 'Tropics']

#1850-1900
a3=0
for i in range(0,50):
    a3=a3+tropics.iloc[i,2]
#mean&std4
m10=a3/len(range(0,50))

sum10=0
for i in range(0,50):
    sum10=sum10+((tropics.iloc[i,2]-m10)**2)

std10=math.sqrt(sum10/(len(range(0,50))-1))
    
#1901-1950
b3=0
for i in range(51,100):
    b3=b3+tropics.iloc[i,2]

#mean&std2
m11=b3/len(range(51,100))

sum11=0
for i in range(51,100):
    sum11=sum11+((tropics.iloc[i,2]-m11)**2)

std11=math.sqrt(sum11/(len(range(51,100))-1))

#1951-2018('present')
c3=0
for i in range(101,169):
    c3=c3+tropics.iloc[i,2]

#mean&std3
m12=c3/len(range(101,169))

sum12=0
for i in range(101,169):
	sum12=sum12+((tropics.iloc[i,2]-m12)**2)

std12=math.sqrt(sum12/(len(range(101,169))-1))

print("the mean of temperature anomalies (in ℃) in the Tropics from 1850 to 1900 is %f with a standard deviation of %f" %(m10,std10))
print("the mean of temperature anomalies (in ℃) in the Tropics from 1901 to 1950 is %f with a standard deviation of %f" %(m11,std11))
print("the mean of temperature anomalies (in ℃) in the Tropics from 1951 to 2018 (present) is %f with a standard deviation of %f\n" %(m12,std12))
# Out:
# the mean of temperature anomalies (in ℃) in the Tropics from 1850 to 1900 is -0.265360 with a standard deviation of 0.161808
# the mean of temperature anomalies (in ℃) in the Tropics from 1901 to 1950 is -0.180980 with a standard deviation of 0.179211
# the mean of temperature anomalies (in ℃) in the Tropics from 1951 to 2018 (present) is 0.151324 with a standard deviation of 0.258883

# %% [markdown]
#  # Plotting and Modelling

# %% [markdown]
# ## Global

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,10))
ax.set_title('Global Temperature Anomalies from 1850-2018')

plt.plot(globe['Year'],globe['Median (℃)'], 'g-')
#plt.plot(globe['Year'],globe['Upper (℃)'],'r-')
#plt.plot(globe['Year'],globe['Lower (℃)'],'b-')

# %%
import matplotlib.pyplot as plt
from matplotlib import pylab
import numpy as np
from scipy.optimize import curve_fit

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,10))
ax.set_title('Global Temperature Anomalies from 1850-2018 -- Exponential Fit')

def func(x,a,b,c):
    return a*np.exp(-b*x)+c

startyear=1850
endyear=2019
list1=np.arange(0,(endyear-startyear),1)

popt,pcov=curve_fit(func,list1,
                    globe['Median (℃)'].values.tolist(),p0=(1,1e-7,1))
print(popt)
plt.plot(list1,globe['Median (℃)'], '-')
plt.plot(list1,func(list1, *popt),'b--')
# Out:
# [ 0.02488695 -0.02237864 -0.36978876]

# %%
import statsmodels
import seaborn as sns
residual=func(list1,*popt)-globe['Median (℃)']

plt.plot(list1,residual)

ss_res=np.sum(residual**2)
ss_tot=np.sum((globe['Median (℃)']-np.mean(globe['Median (℃)']))**2)
r_squared=1-(ss_res/ss_tot)
print(r_squared)
# Out:
# 0.843630745084712

# %% [markdown]
# ## Northern Hemisphere

# %%
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,10))
ax.set_title('Northern Hemipshere Temperature Anomalies from 1850-2018')

plt.plot(nh['Year'],nh['Median (℃)'], 'g-')
#plt.plot(nh['Year'],nh['Upper (℃)'],'r-')
#plt.plot(nh['Year'],nh['Lower (℃)'],'b-')

# %%
import matplotlib.pyplot as plt
from matplotlib import pylab
import numpy as np
from scipy.optimize import curve_fit

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,10))
ax.set_title('Northern Hemisphere Temperature Anomalies from 1850-2018 -- Exponential Fit')

def func(x,a,b,c,d,f,g):
    return a*np.exp(-b*x)+c+(d*np.exp(f*x))+(g*x)

startyear=1850
endyear=2019
list1=np.arange(0,(endyear-startyear),1)

popt,pcov=curve_fit(func,list1,
                    nh['Median (℃)'].values.tolist(),p0=(1,1e-6,1,1,1e-1,.5))
print(popt)
plt.plot(list1,nh['Median (℃)'], '-')
plt.plot(list1,func(list1, *popt),'b--')
# Out:
# [ 2.80958163e-01  5.20794657e-02 -4.84771535e-01  5.60048400e-05
#   5.74355132e-02  3.82507078e-03]
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in multiply
#   # Remove the CWD from sys.path while we load stuff.

# %%
import statsmodels
import seaborn as sns
residual=func(list1,*popt)-nh['Median (℃)']

plt.plot(list1,residual)

ss_res=np.sum(residual**2)
ss_tot=np.sum((nh['Median (℃)']-np.mean(nh['Median (℃)']))**2)
r_squared=1-(ss_res/ss_tot)
print(r_squared)
# Out:
# 0.8113080503568416

# %% [markdown]
# ## Southern Hemisphere

# %%
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,10))
ax.set_title('Southern Hemisphere Temperature Anomalies from 1850-2018')

plt.plot(sh['Year'],sh['Median (℃)'], 'g-')
#plt.plot(sh['Year'],sh['Upper (℃)'],'r-')
#plt.plot(sh['Year'],sh['Lower (℃)'],'b-')

# %%
import matplotlib.pyplot as plt
from matplotlib import pylab
import numpy as np
from scipy.optimize import curve_fit

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,10))
ax.set_title('Southern Hemisphere Temperature Anomalies from 1850-2018 -- Exponential Fit')

def func(x,a,b,c,d,f):
    return a*np.exp(-b*x)+c+(d*np.exp(f*x))

startyear=1850
endyear=2019
list1=np.arange(0,(endyear-startyear),1)

popt,pcov=curve_fit(func,list1,
                    sh['Median (℃)'].values.tolist(),p0=(1,1e-5,1,1,1e-1))
print(popt)
plt.plot(list1,sh['Median (℃)'], '-')
plt.plot(list1,func(list1, *popt),'b--')
# Out:
# [-2.06166064e-03  3.22457888e+01 -4.61495123e-01  5.55567834e-02
#   1.69539143e-02]
# /anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:787: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
import statsmodels
import seaborn as sns
residual=func(list1,*popt)-sh['Median (℃)']

plt.plot(list1,residual)

ss_res=np.sum(residual**2)
ss_tot=np.sum((sh['Median (℃)']-np.mean(sh['Median (℃)']))**2)
r_squared=1-(ss_res/ss_tot)
print(r_squared)
# Out:
# 0.8309929525612335

# %% [markdown]
# ## Tropics

# %%
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,10))
ax.set_title('Tropics Temperature Anomalies from 1850-2018')

plt.plot(tropics['Year'],tropics['Median (℃)'], 'g-')
#plt.plot(tropics['Year'],tropics['Upper (℃)'],'r-')
#plt.plot(tropics['Year'],tropics['Lower (℃)'],'b-')

# %%
import matplotlib.pyplot as plt
from matplotlib import pylab
import numpy as np
from scipy.optimize import curve_fit

fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,10))
ax.set_title('Tropics Temperature Anomalies from 1850-2018 -- Exponential Fit')

def func(x,a,b,c,d,f):
    return a*np.exp(-b*x)+c+(d*np.exp(f*x))

startyear=1850
endyear=2019
list1=np.arange(0,(endyear-startyear),1)

popt,pcov=curve_fit(func,list1,
                    tropics['Median (℃)'].values.tolist(),p0=(1,1e-8,1,1,1e-7))
print(popt)
plt.plot(list1,tropics['Median (℃)'], '-')
plt.plot(list1,func(list1, *popt),'b--')
# Out:
# [ 1.23900334e-04 -4.72019811e-02 -3.56271920e-01  5.56384728e-02
#   1.45727174e-02]

# %%
import statsmodels
import seaborn as sns
residual=func(list1,*popt)-tropics['Median (℃)']

plt.plot(list1,residual)

ss_res=np.sum(residual**2)
ss_tot=np.sum((tropics['Median (℃)']-np.mean(tropics['Median (℃)']))**2)
r_squared=1-(ss_res/ss_tot)
print(r_squared)
# Out:
# 0.7054933690807424

# %% [markdown]
# # Merge

# %%
disaster=pd.read_csv('number-of-natural-disaster-events.csv')
disaster.drop(['Code'],axis=1,inplace=True)
allnd=disaster.loc[lambda disaster: disaster['Entity'] == 'All natural disasters']


drought=disaster.loc[lambda disaster: disaster['Entity'] == 'Drought']

earthquake=disaster.loc[lambda disaster: disaster['Entity'] == 'Earthquake']

et=disaster.loc[lambda disaster: disaster['Entity'] == 'Extreme temperature']

ew=disaster.loc[lambda disaster: disaster['Entity'] == 'Extreme weather']

flood=disaster.loc[lambda disaster: disaster['Entity'] == 'Flood']

landslide=disaster.loc[lambda disaster: disaster['Entity'] == 'Landslide']

mm=disaster.loc[lambda disaster: disaster['Entity'] == 'Mass movement (dry)']

volcanic=disaster.loc[lambda disaster: disaster['Entity'] == 'Volcanic']

wildfire=disaster.loc[lambda disaster: disaster['Entity'] == 'Wildfire']

import matplotlib.pyplot as plt
#fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(10,10))
#ax.set_title('Natural Disasters from 1900-2018')

plt.figure()
plt.subplot(211)
plt.plot(ew['Year'],ew['Number of reported natural disasters (reported disasters)'],label='Extreme Weather')
plt.plot(flood['Year'],flood['Number of reported natural disasters (reported disasters)'],label='Flood')
plt.legend(loc=1,fontsize=7).get_frame().set_edgecolor('white')

plt.subplot(212)

x=globe['Year']
y=globe['Median (℃)']

plt.plot(x[50:],y[50:], label='Anomalies')

plt.show()

# %%
from sklearn.linear_model import LinearRegression

f=ew['Number of reported natural disasters (reported disasters)']

ax=plt.subplot(3,1,1)
plt.plot(y[100:],f[46:],'.')

linreg=LinearRegression().fit(y[100:].values.reshape(-1,1),f[46:].values.reshape(-1,1),sample_weight=None)
plt.plot(y[100:],linreg.predict(y[100:].values.reshape(-1,1)))
ax.set_ylabel('# reported natural disasters')
ax.set_xlabel('Temperature Anomalies (℃)')

print(linreg.score(y[100:].values.reshape(-1,1),f[46:].values.reshape(-1,1)))

ax1=plt.subplot(3,1,3)
g=flood['Number of reported natural disasters (reported disasters)']
plt.plot(y[100:],g[26:],'.')

linreg1=LinearRegression().fit(y[100:].values.reshape(-1,1),g[26:].values.reshape(-1,1),sample_weight=None)
plt.plot(y[100:],linreg1.predict(y[100:].values.reshape(-1,1)))
ax1.set_ylabel('# reported natural disasters')
ax1.set_xlabel('Temperature Anomalies (℃)')

print(linreg1.score(y[100:].values.reshape(-1,1),g[26:].values.reshape(-1,1)))
# Out:
# 0.6814008673139091
# 0.7680327090563479
